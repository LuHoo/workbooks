# %%
import pandas as pd

from ada_fsaudit_bridge import (
    att_sample,
    configure_environment,
    cvs_sample,
    load_dataset,
    lower_bound,
    mus_sample,
    set_notebook_context,
    upper_bound,
)
from scipy.stats import hypergeom

ADA_WORKSHOP_ID = "unknown-workshop"
ADA_CHAPTER = "9"
ADA_NOTEBOOK_SOURCE = "tests/workshop-ir/fixtures/directive-valid-support.Rmd"

def ada_set_context(exercise_ref: str) -> None:
    set_notebook_context(
        chapter=ADA_CHAPTER,
        exercise=exercise_ref,
        notebook=f'{ADA_WORKSHOP_ID}:{ADA_NOTEBOOK_SOURCE}',
    )

configure_environment()

# %% [markdown]
# ## Exercise 9.1

# %% [markdown]
# Python narrative override.

# %%
x = 1

# %%
fs_audit()
